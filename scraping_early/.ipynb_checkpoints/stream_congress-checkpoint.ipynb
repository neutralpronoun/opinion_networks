# %%
import graphviz
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import cython
import tweepy
import json
import requests
import inspect
import re
from tqdm import tqdm
from time import time, sleep
import networkx as nx

# %%
from ast import literal_eval

def load_data(extras = True):

    data = pd.read_csv("politicians_connections_two.csv")
    data["Following"] = data["Following"].apply(literal_eval)

    print(data.head())

    usernames = data["Username"].tolist()
    ids = data["ids"].tolist()
    
    return data, usernames, ids

data, usernames, ids = load_data()
# Out:
#         Party             Name Branch        Username                 ids  \
# 0  Republican    Pete Sessions  House    PeteSessions            24735461
# 1  Democratic   Debbie Dingell  House   RepDebDingell          2970279814
# 2  Democratic  Pramila Jayapal  House      RepJayapal  815733290955112448
# 3  Republican      Rob Wittman  House      RobWittman            15356407
# 4  Democratic  Chellie Pingree  House  chelliepingree            14984637
#
#                                            Following
# 0  {'ids': [1396151678, 815966620300480514, 12912...
# 1  {'ids': [353272992, 300463737, 393541673, 9873...
# 2  {'ids': [35281549, 25535595, 19847765, 1002630...
# 3  {'ids': [834069080, 2964877294, 3686482216, 29...
# 4  {'ids': [38026753, 873135988440223745, 1462548...

# %%
def get_client():

    with open("dev_keys_json.json", "r") as f:
        keys = json.load(f)
    client = tweepy.Client(bearer_token=keys["Bearer_token"],
                           access_token = keys["API_key"],
                           access_token_secret = keys["API_secret_key"],
                           wait_on_rate_limit=True)
    return client

    

def decompose_tweet(self,tweet):
    try:
        retweeted_status = tweet.retweeted_status
        is_retweet = True
        #print(self.count,is_retweet)
        #print(retweeted_status.user.id)
        #print(tweet.user.id)
    except:
        is_retweet = False
        #print(dir(tweet))
        #print("\n")
        self.decompose_tweet(tweet)
        pass
    if is_retweet:
        retweet = tweet
        tweet = tweet.retweeted_status
        #self.decompose_tweet(original)


    user  = tweet.user
    username = user.screen_name
    id = user.id
    text = tweet.text
    print(username, text)       
    


class Listener(tweepy.Stream):
    def __init__(self, keys, ids):
        
        os.chdir("./stream_out")
        
        self.count = 0
        
        super().__init__(keys["API_key"], keys["API_secret_key"],
                                keys["Access_token"], keys["Access_token_secret"])
        


    def on_status(self, tweet):

        #self.decompose_tweet(tweet)
        
        tweet_id = tweet.id
        
        print(tweet._json)
        
        with open(f"{tweet_id}.json", "w") as f:
  
            json.dump(tweet._json, f, indent = 6)
        

        self.count += 1
        #print(self.count,tweet.retweet, tweet.author)
        
        if self.count >= 3:
            self.disconnect()

def get_stream(ids):
    
    with open("dev_keys_api_one.json", "r") as f:
        keys = json.load(f)
    
    client = Listener(keys, ids)

    return client

stream = get_stream(ids)

#stream.filter(follow=ids)
stream.filter(languages=["en"], follow=ids, filter_level = "low")
# Out:
# {'created_at': 'Mon Mar 07 13:22:00 +0000 2022', 'id': 1500824085466603521, 'id_str': '1500824085466603521', 'text': 'RT @MarshaBlackburn: Joe Biden made a conscious decision to destroy our energy independence. Now, Americans are suffering the consequences,…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2768445533, 'id_str': '2768445533', 'name': 'Sal jones', 'screen_name': 'da31957', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 30, 'friends_count': 138, 'listed_count': 0, 'favourites_count': 8228, 'statuses_count': 3869, 'created_at': 'Sat Sep 13 01:16:23 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Mar 06 23:41:14 +0000 2022', 'id': 1500617532797075459, 'id_str': '1500617532797075459', 'text': 'Joe Biden made a conscious decision to destroy our energy independence. Now, Americans are suffering the consequenc… https://t.co/uLcedfle6j', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 278145569, 'id_str': '278145569', 'name': 'Sen. Marsha Blackburn', 'screen_name': 'MarshaBlackburn', 'location': 'Brentwood, TN', 'url': 'http://blackburn.senate.gov', 'description': 'I am honored to serve the people of Tennessee.', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 416573, 'friends_count': 2000, 'listed_count': 3062, 'favourites_count': 1886, 'statuses_count': 14003, 'created_at': 'Wed Apr 06 18:05:33 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': 'EF4244', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1082735690213924864/VRFUWsuH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082735690213924864/VRFUWsuH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/278145569/1549925243', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None ...
# {'created_at': 'Mon Mar 07 13:22:01 +0000 2022', 'id': 1500824088956313606, 'id_str': '1500824088956313606', 'text': 'RT @RepJasonCrow: Ukraine needs fighter jets and it needs them now. \n\nIt may be the single biggest way to tilt the balance of the war at th…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2548854932, 'id_str': '2548854932', 'name': 'El_Pendejo', 'screen_name': 'jabbad101', 'location': 'Bali, Indonesia', 'url': None, 'description': '¿Qué?\n\nVRchat: Hafa?!?!', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 41, 'friends_count': 205, 'listed_count': 0, 'favourites_count': 12634, 'statuses_count': 2692, 'created_at': 'Thu Jun 05 23:29:49 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/808655455882838016/DGWCer4T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/808655455882838016/DGWCer4T_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Mar 06 00:33:36 +0000 2022', 'id': 1500268321060450304, 'id_str': '1500268321060450304', 'text': 'Ukraine needs fighter jets and it needs them now. \n\nIt may be the single biggest way to tilt the balance of the war… https://t.co/ECRsjpi1x6', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1080191866509901826, 'id_str': '1080191866509901826', 'name': 'Rep. Jason Crow', 'screen_name': 'RepJasonCrow', 'location': None, 'url': 'https://crow.house.gov/', 'description': 'Dad. Husband. Former Army Ranger. Assistant Little League Baseball Coach. Proudly Serving Colorado’s 6th in the People’s House. 🏔', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 140824, 'friends_count': 652, 'listed_count': 1029, 'favourites_count': 533, 'statuses_count': 3410, 'created_at': 'Tue Jan 01 19:59:44 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1080818711815176193/HGVcZOy1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080818711815176193/HGVcZOy1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1080191866509901826/1553274406', 'default_profile': False, 'default_profile_image': False, 'follo ...
# {'created_at': 'Mon Mar 07 13:22:01 +0000 2022', 'id': 1500824090491375619, 'id_str': '1500824090491375619', 'text': '@SenMarkKelly Ukraine needs weapons and humanitarian assistance to defend against #Putin. Stop innocent civilian de… https://t.co/Kv3eqCuciG', 'display_text_range': [14, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': 1498848375831203846, 'in_reply_to_status_id_str': '1498848375831203846', 'in_reply_to_user_id': 1324926274888888320, 'in_reply_to_user_id_str': '1324926274888888320', 'in_reply_to_screen_name': 'SenMarkKelly', 'user': {'id': 1500816542250020869, 'id_str': '1500816542250020869', 'name': 'Anastasia Ukrainian', 'screen_name': 'Ukrainian_enot', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'favourites_count': 0, 'statuses_count': 37, 'created_at': 'Mon Mar 07 12:52:56 +0000 2022', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1500820567892668416/2edgsgkl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1500820567892668416/2edgsgkl_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '@SenMarkKelly Ukraine needs weapons and humanitarian assistance to defend against #Putin. Stop innocent civilian deaths. @POTUS, provide #SafeAirliftUkraine #StopPutin', 'display_text_range': [14, 167], 'entities': {'hashtags': [{'text': 'Putin', 'indices': [82, 88]}, {'text': 'SafeAirliftUkraine', 'indices': [137, 156]}, {'text': 'StopPutin', 'indices': [157, 167]}], 'urls': [], 'user_mentions': [{'screen_name': 'SenMarkKelly', 'name': 'Senator Mark Kelly', 'id': 1324926274888888320, 'id_str': '1324926274888888320', 'indices': [0, 13]}, {'screen_name': 'POTUS', 'name': 'President Biden', 'id': 1349149096909668363, 'id_str': '1349149096909668363', 'indices': [121, 127]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'Putin', 'indices': [82, 88]}], 'urls': [{'url': 'https://t.co/Kv3eqCuciG', 'expanded_url': 'https://twitter.com/i/web/status/1500824090491375619', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [{'screen_name': 'SenMarkKelly', 'name': 'Senator Mark Kelly', 'id': 1324926274888888320, 'id_str': '1324926274888888320', 'indices': [0, 13]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1646659321793'}
# {'created_at': 'Mon Mar 07 13:22:02 +0000 2022', 'id': 1500824091397349379, 'id_str': '1500824091397349379', 'text': 'RT @JoyceWhiteVance: Bill Barr is a facile liar. He almost succeeded in preventing investigation of the Ukraine whistleblower complaint. Th…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 126849069, 'id_str': '126849069', 'name': '(((Barbara Albin))) 🌻💙🌻💛🌻💙🌻💛🌻', 'screen_name': 'topmom100', 'location': 'Durham, NC', 'url': 'http://www.facebook.com/no1ladiesdetectiveagency', 'description': 'VACCINES SAVE LIVES', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1127, 'friends_count': 528, 'listed_count': 92, 'favourites_count': 189490, 'statuses_count': 179034, 'created_at': 'Sat Mar 27 05:15:34 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F6EB00', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'B12600', 'profile_sidebar_border_color': 'D9B17E', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1493735474220847105/jauYONk4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1493735474220847105/jauYONk4_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/126849069/1636679185', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Mar 07 03:35:37 +0000 2022', 'id': 1500676518573453313, 'id_str': '1500676518573453313', 'text': 'Bill Barr is a facile liar. He almost succeeded in preventing investigation of the Ukraine whistleblower complaint.… https://t.co/WzmIhKwVJ6', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 548384458, 'id_str': '548384458', 'name': 'Joyce Alene', 'screen_name': 'JoyceWhiteVance', 'location': 'Alabama', 'url': 'https://www.law.ua.edu/directory/People/view/Joyce_Vance', 'description': "@UALawSchool Prof |Legal analyst @MSNBC @NBCNews |Podcasts #SistersInLaw & Cafe Insider|Obama US Atty |25 year fed'l prosecutor |Wife & Mom of 4 |Knits a lot", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 849103, 'friends_count': 1661, 'listed_count': 4950, 'favourites_count': 106047, 'statuses_count': 43696, 'created_at': 'Sun Apr 08 12:20:45 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/952257848301498371/5s24RH-g_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/952257848301498371/5s24 ...
# {'created_at': 'Mon Mar 07 13:22:02 +0000 2022', 'id': 1500824091372175365, 'id_str': '1500824091372175365', 'text': 'RT @RepThomasMassie: I’ve refused to meet with companies, unions, and non-profits that are mandating the vaccines.', 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2604005624, 'id_str': '2604005624', 'name': 'Tommy Ellis', 'screen_name': 'TommyEllis_', 'location': 'Texas', 'url': None, 'description': 'Grace needy, husband of Trish, sons A&C. Multi interests, Sales dude, follow not always = agree. Rom 8:1 is true!', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 313, 'friends_count': 735, 'listed_count': 14, 'favourites_count': 1138, 'statuses_count': 49850, 'created_at': 'Fri Jul 04 19:35:05 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/485287570163519489/_JlOnCPV_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/485287570163519489/_JlOnCPV_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2604005624/1404536548', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Mar 06 15:38:02 +0000 2022', 'id': 1500495931514527746, 'id_str': '1500495931514527746', 'text': 'I’ve refused to meet with companies, unions, and non-profits that are mandating the vaccines.', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 975200486, 'id_str': '975200486', 'name': 'Thomas Massie', 'screen_name': 'RepThomasMassie', 'location': 'Swamp', 'url': 'https://massie.house.gov/media/social.htm', 'description': 'U.S. Rep KY4, #LibertyVariant, co-Chair 2A Caucus, greenest member of congress, MIT 93 BS EE, MIT 96 Master of Science #sassywithmassie #politicalsciencedenier', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 341211, 'friends_count': 5501, 'listed_count': 2668, 'favourites_count': 68226, 'statuses_count': 13153, 'created_at': 'Wed Nov 28 02:33:14 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1339685912872177664/EKpZGLli_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1339685912872177664/EKpZGLli_normal.jpg', 'profile_banner_url': 'https://p ...
# {'created_at': 'Mon Mar 07 13:22:02 +0000 2022', 'id': 1500824095197384705, 'id_str': '1500824095197384705', 'text': '@MarshaBlackburn Oh please… you know how this works lady. Don’t feign ignorance to score cheap political points.', 'display_text_range': [17, 112], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': 1500589718186172421, 'in_reply_to_status_id_str': '1500589718186172421', 'in_reply_to_user_id': 278145569, 'in_reply_to_user_id_str': '278145569', 'in_reply_to_screen_name': 'MarshaBlackburn', 'user': {'id': 23040574, 'id_str': '23040574', 'name': 'Rick 🇺🇸🇺🇸', 'screen_name': 'Cellulrman', 'location': 'Michigan, USA', 'url': None, 'description': 'Professional', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 239, 'friends_count': 456, 'listed_count': 2, 'favourites_count': 7734, 'statuses_count': 8792, 'created_at': 'Fri Mar 06 06:58:42 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '642D8B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_tile': True, 'profile_link_color': 'FF0000', 'profile_sidebar_border_color': '65B0DA', 'profile_sidebar_fill_color': '7AC3EE', 'profile_text_color': '3D1957', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/739067143782682624/Pjr8HUHU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/739067143782682624/Pjr8HUHU_normal.jpg', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'MarshaBlackburn', 'name': 'Sen. Marsha Blackburn', 'id': 278145569, 'id_str': '278145569', 'indices': [0, 16]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1646659322915'}
# {'created_at': 'Mon Mar 07 13:22:03 +0000 2022', 'id': 1500824096241770496, 'id_str': '1500824096241770496', 'text': '@Jim_Jordan At this point, you have to wonder what Jim Jordan does to earn his taxpayer salary. Seriously, besides… https://t.co/wj9feewWvX', 'display_text_range': [12, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': 1500133826470637572, 'in_reply_to_status_id_str': '1500133826470637572', 'in_reply_to_user_id': 18166778, 'in_reply_to_user_id_str': '18166778', 'in_reply_to_screen_name': 'Jim_Jordan', 'user': {'id': 1330123194708193281, 'id_str': '1330123194708193281', 'name': 'ReneeJ', 'screen_name': 'ReneeJ77237138', 'location': 'Chicago, IL', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 42, 'friends_count': 56, 'listed_count': 0, 'favourites_count': 1436, 'statuses_count': 10473, 'created_at': 'Sat Nov 21 12:18:12 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '@Jim_Jordan At this point, you have to wonder what Jim Jordan does to earn his taxpayer salary. Seriously, besides licking the boots of an autocratic madman, what has he done?', 'display_text_range': [12, 175], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'Jim_Jordan', 'name': 'Rep. Jim Jordan', 'id': 18166778, 'id_str': '18166778', 'indices': [0, 11]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/wj9feewWvX', 'expanded_url': 'https://twitter.com/i/web/status/1500824096241770496', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}], 'user_mentions': [{'screen_name': 'Jim_Jordan', 'name': 'Rep. Jim Jordan', 'id': 18166778, 'id_str': '18166778', 'indices': [0, 11]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1646659323164'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 78>()
#      75 stream = get_stream(ids)
#      77 #stream.filter(follow=ids)
# ---> 78 stream.filter(languages=["en"], follow=ids, filter_level = "low")
#
# File ~/miniforge3/envs/networks/lib/python3.9/site-packages/tweepy/streaming.py:270, in Stream.filter(self, follow, track, locations, filter_level, languages, stall_warnings, threaded)
#     267     return self._threaded_connect(method, endpoint, headers=headers,
#     268                                   body=body)
#     269 else:
# --> 270     self._connect(method, endpoint, headers=headers, body=body)
#
# File ~/miniforge3/envs/networks/lib/python3.9/site-packages/tweepy/streaming.py:129, in Stream._connect(self, method, endpoint, params, headers, body)
#     126 if not self.running:
#     127     break
# --> 129 for line in resp.iter_lines(
#     130     chunk_size=self.chunk_size
#     131 ):
#     132     if line:
#     133         self.on_data(line)
#
# File ~/miniforge3/envs/networks/lib/python3.9/site-packages/requests/models.py:804, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795 """Iterates over the response data, one line at a time.  When
#     796 stream=True is set on the request, this avoids reading the
#     797 content at once into memory for large responses.
#     798
#     799 .. note:: This method is not reentrant safe.
#     800 """
#     802 pending = None
# --> 804 for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     806     if pending is not None:
#     807         chunk = pending + chunk
#
# File ~/miniforge3/envs/networks/lib/python3.9/site-packages/requests/models.py:760, in Response.iter_content.<locals>.generate()
#     758 if hasattr(self.raw, 'stream'):
#     759     try:
# --> 760         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761             yield chunk
#     762     except ProtocolError as e:
#
# File ~/miniforge3/envs/networks/lib/python3.9/site-packages/urllib3/response.py:572, in HTTPResponse.stream(self, amt, decode_content)
#     556 """
#     557 A generator wrapper for the read() method. A call will block until
#     558 ``amt`` bytes have been read from the connection or until the
#    (...)
#     569     'content-encoding' header.
#     570 """
#     571 if self.chunked and self.supports_chunked_reads():
# --> 572     for line in self.read_chunked(amt, decode_content=decode_content):
#     573         yield line
#     574 else:
#
# File ~/miniforge3/envs/networks/lib/python3.9/site-packages/urllib3/response.py:764, in HTTPResponse.read_chunked(self, amt, decode_content)
#     761     return
#     763 while True:
# --> 764     self._update_chunk_length()
#     765     if self.chunk_left == 0:
#     766         break
#
# File ~/miniforge3/envs/networks/lib/python3.9/site-packages/urllib3/response.py:694, in HTTPResponse._update_chunk_length(self)
#     692 if self.chunk_left is not None:
#     693     return
# --> 694 line = self._fp.fp.readline()
#     695 line = line.split(b";", 1)[0]
#     696 try:
#
# File ~/miniforge3/envs/networks/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniforge3/envs/networks/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/networks/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(stream.running)

# %%
stream.filter(follow=ids)
